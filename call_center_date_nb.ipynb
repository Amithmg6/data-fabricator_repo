# %%
from faker import Faker
import random
from datetime import datetime, timedelta
import json
import pandas as pd

# %%
def generate_call_center_data(num_records=1000):
    """
    Generates a list of dictionaries for a call center interaction dataset.
    """
    fake = Faker() # Use 'en_IN' for Indian-specific data
    records = []
    
    # Pre-generate lists of agents, customers, and common issues for consistency
    agents = [{"id": fake.uuid4(), "name": fake.name()} for _ in range(20)]
    customers = [{"id": fake.uuid4(), "name": fake.name()} for _ in range(500)]
    
    common_issues = [
        "Billing Inquiry", "Technical Support", "Product Information", 
        "Order Status", "Complaint Resolution", "Account Activation",
        "Subscription Cancellation", "Service Downgrade", "Login Issue"
    ]
    
    for i in range(num_records):
        # Select random agent and customer
        agent = random.choice(agents)
        customer = random.choice(customers)
        
        # Determine issue and resolution status
        issue = random.choice(common_issues)
        resolution_status = "Resolved" if random.random() < 0.8 else "Unresolved"
        
        # Generate a realistic call start and end time
        call_start = fake.date_time_this_year()
        call_duration_seconds = random.randint(60, 1200) # 1 to 20 minutes
        call_end = call_start + timedelta(seconds=call_duration_seconds)
        
        # Create the interaction record
        record = {
            "interaction_id": fake.unique.uuid4(),
            "timestamp": call_start.isoformat(),
            "agent_id": agent["id"],
            "agent_name": agent["name"],
            "customer_id": customer["id"],
            "customer_name": customer["name"],
            "call_duration_seconds": call_duration_seconds,
            "issue_category": issue,
            "resolution_status": resolution_status,
            "call_summary": fake.text(max_nb_chars=150) # A short, fake summary
        }
        records.append(record)
        
    return records

# %%
call_data = generate_call_center_data()
print(f"Generated {len(call_data)} call center records.")
# Out:
# Generated 1000 call center records.

# %% [markdown]
# * SAVE AS JSON

# %%
import json
with open('call_center_data.json', 'w') as f:
    json.dump(call_data, f, indent=4)

# %% [markdown]
# * SAVE AS CSV

# %%
import pandas as pd
df = pd.DataFrame(call_data)
df.to_csv('call_center_data.csv', index=False)

# %%
from faker import Faker
import random
from datetime import datetime, timedelta

# %%
from faker import Faker
import random
from datetime import datetime, timedelta

def generate_call_center_data(num_records=1000):
    """
    Generates a list of dictionaries for a call center interaction dataset
    with full conversations between agents and customers.
    """
    fake = Faker()
    records = []
    
    # Pre-generate lists of agents, customers, and common issues for consistency
    agents = [{"id": fake.uuid4(), "name": fake.name()} for _ in range(20)]
    customers = [{"id": fake.uuid4(), "name": fake.name()} for _ in range(500)]
    
    common_issues = [
        "Billing Inquiry", "Technical Support", "Product Information", 
        "Order Status", "Complaint Resolution", "Account Activation",
        "Subscription Cancellation", "Service Downgrade", "Login Issue"
    ]
    
    for i in range(num_records):
        agent = random.choice(agents)
        customer = random.choice(customers)
        issue = random.choice(common_issues)
        resolution_status = "Resolved" if random.random() < 0.8 else "Unresolved"
        
        call_start = fake.date_time_this_year()
        call_duration_seconds = random.randint(60, 1200)
        call_end = call_start + timedelta(seconds=call_duration_seconds)
        
        # --- Generate the conversation as a list of dictionaries ---
        conversation = []
        
        # Opening
        conversation.append({"speaker": "agent", "text": f"Hello, thank you for calling. My name is {agent['name']}. How may I help you today?"})
        conversation.append({"speaker": "customer", "text": f"Hi, I'm calling about a {issue.lower()}."})
        
        # Main dialogue
        num_exchanges = random.randint(2, 6)
        for _ in range(num_exchanges):
            customer_response = fake.text(max_nb_chars=100)
            agent_response = fake.text(max_nb_chars=100)
            conversation.append({"speaker": "customer", "text": customer_response})
            conversation.append({"speaker": "agent", "text": agent_response})
        
        # Closing
        if resolution_status == "Resolved":
            conversation.append({"speaker": "agent", "text": "Thank you for your patience. The issue has been resolved. Is there anything else I can assist you with?"})
        else:
            conversation.append({"speaker": "agent", "text": "I'm sorry, I'm unable to resolve this issue right now. I'll escalate it for you."})
            
        conversation.append({"speaker": "customer", "text": "Thank you for your help. Goodbye."})

        # Create the interaction record without the 'call_summary' field
        record = {
            "interaction_id": fake.unique.uuid4(),
            "timestamp": call_start.isoformat(),
            "agent_id": agent["id"],
            "agent_name": agent["name"],
            "customer_id": customer["id"],
            "customer_name": customer["name"],
            "call_duration_seconds": call_duration_seconds,
            "issue_category": issue,
            "resolution_status": resolution_status,
            "conversation": conversation, # The conversation field
        }
        records.append(record)
        
    return records

# %%
call_data = generate_call_center_data()
print(f"Generated {len(call_data)} call center records with conversations.")

# Example of a single record
import pprint
pprint.pprint(call_data[0:3])
# Out:
# Generated 1000 call center records with conversations.
# [{'agent_id': '6d1a634c-df88-4731-a5ea-330c68ab1669',
#   'agent_name': 'Janet Howell MD',
#   'call_duration_seconds': 295,
#   'conversation': [{'speaker': 'agent',
#                     'text': 'Hello, thank you for calling. My name is Janet '
#                             'Howell MD. How may I help you today?'},
#                    {'speaker': 'customer',
#                     'text': "Hi, I'm calling about a technical support."},
#                    {'speaker': 'customer',
#                     'text': 'Eat notice effect reality cultural tell. Well '
#                             'sport available staff find your organization '
#                             'law.'},
#                    {'speaker': 'agent',
#                     'text': 'Building region learn know can on. Front '
#                             'Republican street material wonder blue around '
#                             'movie.'},
#                    {'speaker': 'customer',
#                     'text': 'Trip water people board. Together least road fast '
#                             'character improve.'},
#                    {'speaker': 'agent',
#                     'text': 'State guess seat seem rule. Entire help same ever '
#                             'reason.'},
#                    {'speaker': 'customer',
#                     'text': 'Scientist white talk company choose it agency. '
#                             'Attention large learn listen kitchen nearly '
#                             'follow.'},
#                    {'speaker': 'agent',
#                     'text': 'Over public respond green drive answer within Mr. '
#                             'Stock common sure painting side recently.'},
#                    {'speaker': 'customer',
#                     'text': 'Half speak her consider low hear.'},
#                    {'speaker': 'agent',
#                     'text': 'Whole stuff country everything media according '
#                             'leg. In poor free record. Main instead teach '
#                             'upon.'},
#                    {'speaker': 'customer',
#                     'text': 'Expert service affect remain. Foreign house '
#                             'investment weight. Smile political positive next '
#                             'share.'},
#                    {'speaker': 'agent',
#                     'text': 'Again law visit same mean fill toward.'},
#                    {'speaker': 'agent',
#                     'text': "I'm sorry, I'm unable to resolve this issue right "
#                             "now. I'll escalate it for you."},
#                    {'speaker': 'customer',
#                     'text': 'Thank you for your help. Goodbye.'}],
#   'customer_id': '43932e61-82f0-4654-af20-c628a07009ef',
#   'customer_name': 'Daniel Miller',
#   'interaction_id': '63081384-9319-4c0e-8e4c-56fd77155301',
#   'issue_category': 'Technical Support',
#   'resolution_status': 'Unresolved',
#   'timestamp': '2025-05-07T01:38:22'},
#  {'agent_id': '0379ea7f-0d8f-418f-86b8-2d6ba047fb48',
#   'agent_name': 'Tina Novak',
#   'call_duration_seconds': 540,
#   'conversation': [{'speaker': 'agent',
#                     'text': 'Hello, thank you for calling. My name is Tina '
#                             'Novak. How may I help you today?'},
#                    {'speaker': 'customer',
#                     'text': "Hi, I'm calling about a order status."},
#                    {'speaker': 'customer',
#                     'text': 'Big be major blood for alone. Get near fight. '
#                             'Area room note already itself modern power '
#                             'executive.'},
#                    {'speaker': 'agent',
#                     'text': 'Economic peace law value. Do the purpose. Current '
#                             'current affect after carry simple.'},
#                    {'speaker': 'customer',
#                     'text': 'Economy hit nearly. Often be sometimes offer.'},
#                    {'speaker': 'agent',
#                     'text': 'Two true enter itself peace. Task dream executive '
#                             'picture.'},
#                    {'speaker': 'customer',
#                     'text': 'Hand least there enter. Program put nation board '
#                             'arrive notice side.'},
#                    {'speaker': 'agent',
#                     'text': 'Same toward relate affect home teacher.'},
#                    {'speaker': 'customer',
#                     'text': 'Land certainly others discover join hold oil. Two '
#                             'capital figure age writer turn require.'},
#                    {'speaker': 'agent',
#                     'text': 'Speak pick financial. Despite stock class someone '
#                             'west off social. Late another son which.'},
#                    {'speaker': 'customer',
#                     'text': 'Goal various trial hair. Better way so event.'},
#                    {'speaker': 'agent',
#                     'text': 'Like lot might.\n'
#                             'Value decision accept eye. Analysis feeling '
#                             'home.'},
#                    {'speaker': 'agent',
#                     'text': 'Thank you for your patience. The issue has been '
#                             'resolved. Is there anything else I can assist you '
#                             'with?'},
#                    {'speaker': 'customer',
#                     'text': 'Thank you for your help. Goodbye.'}],
#   'customer_id': 'e83282c8-9fb9-41d7-8e2b-970958ca8ebb',
#   'customer_name': 'Kaitlyn Neal',
#   'interaction_id': '1b46445a-99f4-47c4-8dc2-2143ce9d4602',
#   'issue_category': 'Order Status',
#   'resolution_status': 'Resolved',
#   'timestamp': '2025-03-02T08:32:54'},
#  {'agent_id': '61ae7674-3160-4392-b9a5-758b53d9f16a',
#   'agent_name': 'Jessica Allen',
#   'call_duration_seconds': 892,
#   'conversation': [{'speaker': 'agent',
#                     'text': 'Hello, thank you for calling. My name is Jessica '
#                             'Allen. How may I help you today?'},
#                    {'speaker': 'customer',
#                     'text': "Hi, I'm calling about a complaint resolution."},
#                    {'speaker': 'customer',
#                     'text': 'General really person dog study leader. Fear feel '
#                             'page report rather detail.'},
#                    {'speaker': 'agent',
#                     'text': 'Either event expect kind still issue none. '
#                             'Prevent main there. Represent leader difficult.'},
#                    {'speaker': 'customer',
#                     'text': 'Sound say central community about appear '
#                             'individual bill. Black investment four.'},
#                    {'speaker': 'agent',
#                     'text': 'Free source series college. Seven move goal eight '
#                             'I. Out among wall answer.'},
#                    {'speaker': 'customer',
#                     'text': 'Base official must industry. Class painting '
#                             'message successful so resource.'},
#                    {'speaker': 'agent',
#                     'text': 'Movie mind tell loss upon family third. Gun '
#                             'around common approach letter kind.'},
#                    {'speaker': 'customer',
#                     'text': 'Weight perhaps garden western. Check only require '
#                             'sing couple study parent price.'},
#                    {'speaker': 'agent',
#                     'text': 'Hair less player understand reason. While '
#                             'certainly chance development health. Give hot '
#                             'save plant.'},
#                    {'speaker': 'customer',
#                     'text': 'Sit buy serve over few. Order nothing reduce blue '
#                             'west.'},
#                    {'speaker': 'agent',
#                     'text': 'Mr member daughter better. Might attorney '
#                             'experience ground yourself.'},
#                    {'speaker': 'customer',
#                     'text': 'Memory arrive rest country appear hair. Mention '
#                             'fill according able line.'},
#                    {'speaker': 'agent',
#                     'text': 'Step spring key. Reach later consider most '
#                             'realize down reason.'},
#                    {'speaker': 'agent',
#                     'text': 'Thank you for your patience. The issue has been '
#                             'resolved. Is there anything else I can assist you '
#                             'with?'},
#                    {'speaker': 'customer',
#                     'text': 'Thank you for your help. Goodbye.'}],
#   'customer_id': 'a0b1730a-0a7f-4215-972a-76843f510af6',
#   'customer_name': 'George Smith',
#   'interaction_id': '80d7acf3-095a-4172-b31b-16db63400fa3',
#   'issue_category': 'Complaint Resolution',
#   'resolution_status': 'Resolved',
#   'timestamp': '2025-04-11T00:38:37'}]
